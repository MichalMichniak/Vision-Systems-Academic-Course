# %% [markdown]
# Test instalacji Python i OpenCV.
# Po uruchomieniu pownien się pojawić obrazek pawiana.

# %%
import cv2                              # OpenCV (image processing library)
import os                               # Operating system library
from matplotlib import pyplot as plt    # Matplotlib (display images)

# Load required files
if not os.path.exists("mandril.jpg") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/00_Test/mandril.jpg

# Read file from disk
I = cv2.imread('mandril.jpg')
#Converts from one colour space to the other (here only change BGR to RGB)
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

# Matplotlib display
plt.imshow(I)
plt.xticks([]), plt.yticks([])  # Hides the graph ticks and x / y axis
plt.show()
# Out:
# --2022-03-01 14:46:31--  https://raw.githubusercontent.com/vision-agh/poc_sw/master/00_Test/mandril.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8002::154, 2606:50c0:8001::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77244 (75K) [image/jpeg]
# Saving to: 'mandril.jpg'
#
#      0K .......... .......... .......... .......... .......... 66%  530K 0s
#     50K .......... .......... .....                           100% 20,9M=0,1s
#
# 2022-03-01 14:46:32 (790 KB/s) - 'mandril.jpg' saved [77244/77244]
